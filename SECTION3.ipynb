# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghostalp07/Skill_assesment/blob/main/SECTION3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)

# %%
import anthropic
from anthropic import RateLimitError

def call_anthropic_with_retry(prompt, model="claude-3-5-sonnet-20240620"):
    client = anthropic.Anthropic(api_key="your_api_key")
    max_retries = 3

    for attempt in range(max_retries + 1):
        try:
            message = client.messages.create(
                model=model,
                max_tokens=200,
                messages=[{"role": "user", "content": prompt}]
            )
            return message.content[0].text
        except RateLimitError as e:
            if attempt == max_retries:
                raise e
            wait_time = (attempt + 1) * 2
            print(f"Rate limit hit. Retrying in {wait_time}s...")
            time.sleep(wait_time)

# %% [markdown]
# 3

# %%
"""You are the Brand Voice Guardian. Your mission is to audit and rewrite marketing copy to ensure it adheres strictly to our Brand Guidelines.
Guidelines:
Voice: Confident, empathetic, and professional.
Vocabulary: Use active verbs; avoid corporate jargon (e.g., "synergy," "low-hanging fruit").
Constraint: Keep the core message identical, but change the delivery. If the input is overly casual or aggressive, pivot it to "Warm Professionalism."
Task: Analyze the provided copy. First, identify "Off-Brand" phrases. Second, provide the "On-Brand" rewrite."""

# %% [markdown]
# **3**

# %% [markdown]
# first 5/10
# second 5/10
# third 6/10
# every picture was good interms of color contrast and clear wording and vocab but if you are going for this image is as a proper advertisement post on any place then it will not be great choice cause its lackc the attraction and vibe
